# %% [markdown]
# Linear Regression

# %% [markdown]
# Import libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# print tensor flow version

# %%
print(tf.__version__)

# %% [markdown]
# Generate Data

# %%
# actual weight = 2 and actual bias = 0.9
x = np.linspace(0, 3, 120)
y = 2 * x + 0.9 + np.random.randn(*x.shape) * 0.3

# %% [markdown]
# Show the data

# %%
plt.scatter(x,y, label="input data set")

# %% [markdown]
# Define linear model

# %%
class LinearModel:
    def __call__(self, x):
        return self.Weight * x + self.Bias
    
    def __init__(self):
        self.Weight = tf.Variable(11.0)
        self.Bias = tf.Variable(12.0)

# %% [markdown]
# Loss function and training function

# %%
def loss(y, pred):
    return tf.reduce_mean(tf.square(y - pred))

def train(linear_model, x, y, lr=0.12):
    with tf.GradientTape() as t:
        current_loss = loss(y, linear_model(x))

    lr_weight, lr_bias = t.gradient(current_loss, [linear_model.Weight, linear_model.Bias])
    linear_model.Weight.assign_sub(lr * lr_weight)
    linear_model.Bias.assign_sub(lr * lr_bias)

# %%
linear_model = LinearModel()
Weights, Biases = [], []
losed =[]
epocs=[]
epochs = 800
for epoch_count in range(epochs):
    Weights.append(linear_model.Weight.numpy()) 
    Biases.append(linear_model.Bias.numpy())
    real_loss = loss(y, linear_model(x))
    
    train(linear_model, x, y, lr=0.12)
    #print(f"Epoch count {epoch_count}: Loss value: {real_loss.numpy()}")
    epocs.append(epoch_count)
    losed.append(real_loss.numpy())

# %% [markdown]
# print out model

# %%
linear_model.Weight.numpy(), linear_model.Bias.numpy()

# %% [markdown]
# printout lose

# %%
RMSE = loss(y, linear_model(x))

# %%
RMSE.numpy()

# %% [markdown]
# fitted lines

# %%
fitted=linear_model(x)

# %%
plt.scatter(x,y, label="input data set")
plt.scatter(x,fitted, label="simulated")

# %% [markdown]
# Loses of each loop

# %%
#print(epocs)
print(losed)

# %%
plt.scatter(epocs,losed, label="loses")

# %% [markdown]
# Home Work
# Please ajust the simulation

# %% [markdown]
# Non-linear Regression

# %% [markdown]
# Simulate Data

# %%
# actual weight = 2 and actual bias = 0.9
x = np.linspace(0, 3, 120)
y = 3.5*x**2+2 * x + 0.9 + np.random.randn(*x.shape) * 0.3
plt.scatter(x,y, label="input data set")

# %% [markdown]
# Setup Non-linear model

# %%
class NonLinearModel:
    def __call__(self, x):
        return self.Weight2*x**2+self.Weight * x + self.Bias
    
    def __init__(self):
        self.Weight2 = tf.Variable(10.0)
        self.Weight = tf.Variable(11.0)
        self.Bias = tf.Variable(12.0)

# %% [markdown]
# setup loos and training

# %%
def loss(y, pred):
    return tf.reduce_mean(tf.square(y - pred))

def train(nonlinear_model, x, y, lr=0.12):
    with tf.GradientTape() as t:
        current_loss = loss(y, nonlinear_model(x))

    lr_weight2, lr_weight, lr_bias = t.gradient(current_loss, [nonlinear_model.Weight2,nonlinear_model.Weight, nonlinear_model.Bias])
    nonlinear_model.Weight2.assign_sub(lr * lr_weight2)
    nonlinear_model.Weight.assign_sub(lr * lr_weight)
    nonlinear_model.Bias.assign_sub(lr * lr_bias)

# %% [markdown]
# Train the model

# %%
nonlinear_model = NonLinearModel()
Weights2,Weights, Biases = [],[], []
losed =[]
epocs=[]
epochs = 800
for epoch_count in range(epochs):
    Weights2.append(nonlinear_model.Weight2.numpy()) 
    Weights.append(nonlinear_model.Weight.numpy()) 
    Biases.append(nonlinear_model.Bias.numpy())
    real_loss = loss(y, nonlinear_model(x))
    
    train(nonlinear_model, x, y, lr=0.01)
    print(f"Epoch count {epoch_count}: Loss value: {real_loss.numpy()} ")
    epocs.append(epoch_count)
    losed.append(real_loss.numpy())

# %% [markdown]
# display the model result

# %%
nonlinear_model.Weight2.numpy(),nonlinear_model.Weight.numpy(), nonlinear_model.Bias.numpy()

# %% [markdown]
# Display the loose

# %%
RMSE = loss(y, nonlinear_model(x))
RMSE.numpy()

# %% [markdown]
# Calcuate the fitted

# %%
fitted=nonlinear_model(x)

# %% [markdown]
# Draw the chart

# %%
plt.scatter(x,y, label="input data set")
plt.scatter(x,fitted, label="simulated")

# %% [markdown]
# Display the loose history

# %%
plt.scatter(epocs,losed, label="loses")

# %% [markdown]
# Analysis covid-19 data
# #data soure https://ourworldindata.org/coronavirus-source-data
# covid19file1="https://covid.ourworldindata.org/data/owid-covid-data.csv"
# #covid19file2="https://covid.ourworldindata.org/data/ecdc/full_data.csv"
# data=pd.read_csv(covid19file1)

# %%
#data soure https://ourworldindata.org/coronavirus-source-data
covid19file1="https://covid.ourworldindata.org/data/owid-covid-data.csv"
#covid19file2="https://covid.ourworldindata.org/data/ecdc/full_data.csv"
data=pd.read_csv(covid19file1)

# %% [markdown]
# Data field

# %%
data.head()

# %%
data.head(n=1)

# %% [markdown]
# Data Frames Pandas DataFrames are data structures that contain:
#
# Data: organized in two dimensions, rows and columns
#
# Labels: that correspond to the rows and columns
#
# Look at all the columns of the file

# %%
data.columns

# %% [markdown]
# get the continent column and assign it to a new variable called continent

# %%
continent=data['continent']
print(continent)

# %% [markdown]
# look at the data types of each column

# %%
data.dtypes

# %% [markdown]
# number of rows and columns

# %%
data.shape

# %% [markdown]
# Filter
#
# get the data from China

# %%
chinafilter=data['location'] =='China'

print(usafilter)

# %%
data[chinafilter]

# %% [markdown]
# Ploting data

# %%
import matplotlib.pyplot as plt
data.plot()
plt.show()

# %%
chinaCases=data[chinafilter]
chinaCases.plot()
plt.show()

# %% [markdown]
# draw colum 4 (total case)

# %% [markdown]
# add label and title, legend

# %%
chinaCases=data[chinafilter]
chinaCases.iloc[:, 4].plot(title='Covid 19 China number', legend=True)
plt.xlabel('index')
plt.ylabel('count')
plt.show()

# %% [markdown]
# display total cases and new cases

# %%
chinaCases=data[chinafilter]
chinaCases.plot(x='date', y=['total_cases','new_cases','total_deaths'], title='Covid 19 China number', legend=True)
plt.xlabel('index')
plt.ylabel('count')
plt.show()

# %% [markdown]
# use date as index

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

covid19file1="https://covid.ourworldindata.org/data/owid-covid-data.csv"
#covid19file2="https://covid.ourworldindata.org/data/ecdc/full_data.csv"
data=pd.read_csv(covid19file1,usecols=['date','new_cases','total_deaths','new_deaths','location'], parse_dates=['date'])
datatouse=data[chinafilter]

datatouse.set_index('date',inplace=True)

#plot data
fig, ax = plt.subplots(figsize=(15,7))
datatouse.plot(ax=ax)

#set ticks every week
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %% [markdown]
# Total cases analysis

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

covid19file1="https://covid.ourworldindata.org/data/owid-covid-data.csv"
#covid19file2="https://covid.ourworldindata.org/data/ecdc/full_data.csv"
data=pd.read_csv(covid19file1,usecols=['date','total_cases'], parse_dates=['date'])
datatouse=data[chinafilter]

datatouse.set_index('date',inplace=True)

#plot data
fig, ax = plt.subplots(figsize=(15,7))
datatouse.plot(ax=ax)

#set ticks every week
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %%
print(datatouse)

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

covid19file1="https://covid.ourworldindata.org/data/owid-covid-data.csv"
#covid19file2="https://covid.ourworldindata.org/data/ecdc/full_data.csv"
data=pd.read_csv(covid19file1,usecols=['date','total_cases','location'], parse_dates=['date'])
datatouse=data[data['location']=='United States']

datatouse.set_index('date',inplace=True)

#plot data
fig, ax = plt.subplots(figsize=(15,7))
datatouse=datatouse.replace(np.nan, 0) 

datatouse.plot(ax=ax)

#set ticks every week
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %% [markdown]
# Covid-model 1

# %%
class Cov19ModelLinear:
    def __call__(self, x):
        return self.Weight * x + self.Bias
    
    def __init__(self):
        self.Weight = tf.Variable(0.2)
        self.Bias = tf.Variable(0.1)

# %% [markdown]
# Loss function and training function

# %%
def loss(y, pred):
    return tf.reduce_mean(tf.square(y - pred))

def train(model, x, y, lr=0.12):
    with tf.GradientTape() as t:
        current_loss = loss(y, model(x))

    lr_weight, lr_bias = t.gradient(current_loss, [model.Weight, model.Bias])
    model.Weight.assign_sub(lr * lr_weight)
    model.Bias.assign_sub(lr * lr_bias)
    print(f'weight {model.Weight} bias: {model.Bias}')
    #dff=y-model(x)
    #print(dff)

# %%
import datetime

y=datatouse.to_numpy()[:,1]/10000
norm = np.linalg.norm(y)
y=y/norm
#x=datatouse.index.to_numpy()
x=(datatouse.index.to_numpy() - np.datetime64('2019-12-31'))/(24*60*60*1000000000)

print(y)
#print(x)
#print(datatouse)

# %%
plt.scatter(x,y, label="input data set")

# %%
model = Cov19ModelLinear()
Weights, Biases = [], []
losed =[]
epocs=[]
epochs = 20

for epoch_count in range(epochs):
    Weights.append(model.Weight.numpy()) 
    Biases.append(model.Bias.numpy())
    real_loss = loss(y, model(x))
    train(model, x, y, lr=0.02)
    print(f"Epoch count {epoch_count}: Loss value: {real_loss.numpy()}")
    epocs.append(epoch_count)
    losed.append(real_loss.numpy())

# %% [markdown]
# Covnert date to days

# %%
import datetime
x=(datatouse.index.to_numpy() - np.datetime64('2019-12-31'))/(24*60*60*1000000000)

# %%
plt.scatter(x,y, label="input data set")

# %%
model = Cov19ModelLinear()
Weights, Biases = [], []
losed =[]
epocs=[]
epochs = 1

for epoch_count in range(epochs):
    Weights.append(model.Weight.numpy()) 
    Biases.append(model.Bias.numpy())
    real_loss = loss(y, model(x))
    train(model, x, y, lr=0.001)
    print(f"Epoch count {epoch_count}: Loss value: {real_loss.numpy()}, Weight:{model.Weight.numpy()}, Bias:{model.Bias.numpy()}")
    epocs.append(epoch_count)
    losed.append(real_loss.numpy())

# %%
fitted=model(x)
plt.scatter(x,y, label="input data set")
plt.scatter(x,fitted, label="fited data set")

# %% [markdown]
# try non linear

# %% [markdown]
# Covid-model 1

# %%
class Cov19ModelnonLinear:
    def __call__(self, x):
        return self.Weight2 * x * x + self.Weight * x + self.Bias
    
    def __init__(self):
        self.Weight2 = tf.Variable(0.0001)
        self.Weight = tf.Variable(1.0)
        self.Bias = tf.Variable(.05)

# %% [markdown]
# Loss function and training function

# %%
def loss(y, pred):
    return tf.reduce_mean(tf.square(y - pred))

def train(model, x, y, lr=0.12):
    with tf.GradientTape() as t:
        current_loss = loss(y, model(x))

    lr_weight2, lr_weight, lr_bias = t.gradient(current_loss, [model.Weight2, model.Weight, model.Bias])
    model.Weight2.assign_sub(lr * lr_weight2)
    model.Weight.assign_sub(lr * lr_weight)
    model.Bias.assign_sub(lr * lr_bias)
    #print(f'weight2 {model.Weight2} weight {model.Weight} bias: {model.Bias}')
    #dff=y-model(x)
    #print(dff)

# %%
model = Cov19ModelnonLinear()
Weights2, Weights, Biases = [], [], []
losed =[]
epocs=[]
epochs = 10000000

for epoch_count in range(epochs):
    Weights2.append(model.Weight2.numpy()) 
    Weights.append(model.Weight.numpy()) 
    Biases.append(model.Bias.numpy())
    real_loss = loss(y, model(x))
    train(model, x, y, lr=0.0000000002)
    #print(f"Epoch count {epoch_count}: Loss value: {real_loss.numpy()}, Weight2:{model.Weight2.numpy()}, Weight:{model.Weight.numpy()}, Bias:{model.Bias.numpy()}")
    epocs.append(epoch_count)
    losed.append(real_loss.numpy())
print("done")

# %% [markdown]
# print out model

# %%
model.Weight2.numpy(),model.Weight.numpy(), model.Bias.numpy()

# %% [markdown]
# printout lose

# %%
RMSE = loss(y, model(x))

# %%
RMSE.numpy()

# %% [markdown]
# fitted lines

# %%
fitted=model(x)
print(fitted)

# %%
print(fitted)
#plt.scatter(x,y, label="input data set")
plt.scatter(x,fitted, label="simulated")

# %% [markdown]
# Loses of each loop

# %%
#print(epocs)
print(losed)

# %%
plt.scatter(epocs,losed, label="loses")
