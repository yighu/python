# %% [markdown]
# # 1. Fill the missing pieces
# Fill the `____` parts in the code below.

# %%
words = ['PYTHON', 'JOHN', 'chEEse', 'hAm', 'DOE', '123']
upper_case_words = []

for ____ in words:
    if ____.isupper():
        ____.append(____)

# %%
assert upper_case_words == ['PYTHON', 'JOHN', 'DOE']

# %% [markdown]
# # 2. Calculate the sum of dict values
# Calculate the sum of the values in `magic_dict` by taking only into account numeric values (hint: see [isinstance](https://docs.python.org/3/library/functions.html#isinstance)). if still need help, please check the example how to check if something is a number

# %%
magic_dict = dict(val1=44, val2='secret value', val3=55.0, val4=1)

# %%
# Your implementation
sum_of_values =

# %%
assert sum_of_values == 100

# %% [markdown]
# Example how to check if something is a number

# %%
import numbers
mixed = [1,3,5.0, 6.0]
total =[a for a in mixed if isinstance(a, numbers.Number)]

# %% [markdown]
# # 3. Create a list of strings based on a list of numbers
# The rules:
# * If the number is a multiple of five and odd, the string should be `'five odd'`
# * If the number is a multiple of five and even, the string should be `'five even'`
# * If the number is odd, the string is `'odd'`
# * If the number is even, the string is `'even'`

# %%
numbers = [1, 3, 4, 6, 81, 80, 100, 95]

# %%
# Your implementation
my_list =

# %%
assert my_list == ['odd', 'odd', 'even', 'even', 'odd', 'five even', 'five even', 'five odd']

# %%
import numbers
mixed = [1,3,5.0, 6.0]
total =[a for a in mixed if isinstance(a, numbers.Number)]
# Out:
# [1, 3, 5.0, 6.0]
