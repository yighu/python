# %% [markdown]
# # 1. Creating formulas
# Write the following mathematical formula in Python:
#
# \begin{align}
#  result = 6a^3 - \frac{8b^2 }{4c} + 11
# \end{align}

# %%
a = 2
b = 3
c = 2

# %%
# Your formula here:
result = null

# %%
assert result == 50

# %% [markdown]
# # 2. Floating point pitfalls
# Show that `0.1 + 0.2 == 0.3`

# %%
assert (0.1 +0.2 == 0.3)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-a3799ef58349> in <module>()
# ----> 1 assert (0.1 +0.2 == 0.3)
#
# AssertionError:

# %%
# Your solution here
from decimal import Decimal
assert ()
# This won't work:
# assert 0.1 + 0.2 == 0.3

# %% [markdown]
# Magic coins

# %%
found_coins = 20
magic_coins = 10
stolen_coins = 3
print(found_coins + magic_coins * 365 - stolen_coins * 52)
stolen_coins = 2
print(found_coins + magic_coins * 365 - stolen_coins * 52)
magic_coins = 13
print(found_coins + magic_coins * 365 - stolen_coins * 52)
# Out:
# 3514
# 3566
# 4661
